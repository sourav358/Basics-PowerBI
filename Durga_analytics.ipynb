# %% [markdown]
# <a href="https://colab.research.google.com/github/sourav358/Basics-PowerBI/blob/main/Durga_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
trade_data = pd.read_csv("/content/Trades_Dataset.csv")

# %%
trade_data.head()
# Out:
#   trade_id   trader commodity  trade_date   price  volume
# 0     T001    Alice       Oil  2025-09-05  160.20      81
# 1     T002    Alice       Oil  2025-09-10  239.86      25
# 2     T003      Bob       Oil  2025-09-04  277.41      23
# 3     T004      Bob      Gold  2025-09-09  238.78     239
# 4     T005  Charlie      Gold  2025-09-01  391.46      91

# %%
Market_price = pd.read_csv("/content/Market_Prices_Dataset.csv")

# %%
Market_price.head()
# Out:
#   commodity        date  closing_price
# 0       Oil  2025-09-01         373.60
# 1       Oil  2025-09-02         332.91
# 2       Oil  2025-09-03         395.46
# 3       Oil  2025-09-04         473.00
# 4       Oil  2025-09-05         440.24

# %%
Ref_data = pd.read_csv("/content/Reference_Data_Dataset.csv")

# %%
Ref_data.head()
# Out:
#   commodity    unit currency
# 0       Oil  Barrel      USD
# 1       Gas   MMBtu      USD
# 2     Power     MWh      EUR
# 3      Coal     Ton      USD
# 4      Gold   Ounce      USD

# %% [markdown]
# Checking Null Values

# %%
Market_price.isnull().sum()
# Out:
# commodity        0
# date             0
# closing_price    0
# dtype: int64

# %%
trade_data.isnull().sum()
# Out:
# trade_id      0
# trader        0
# commodity     0
# trade_date    0
# price         0
# volume        0
# dtype: int64

# %%
Ref_data.isnull().sum()
# Out:
# commodity    0
# unit         0
# currency     0
# dtype: int64

# %% [markdown]
# Check Negative Volumes

# %%
trade_data['volume']<=0
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: volume, dtype: bool

# %% [markdown]
# Standardize the data columns

# %%
trade_data['trade_date'] = pd.to_datetime(trade_data['trade_date'])
Market_price['date'] = pd.to_datetime(Market_price['date'])

# %%
print("inavlid trade_dates = ", trade_data['trade_date'].isnull().sum())
print("Invalid date =",Market_price['date'].isnull().sum())
# Out:
# inavlid trade_dates =  0
# Invalid date = 0

# %% [markdown]
# Importing Cleaned DataSet

# %%
trade_data.to_csv("Cleaned_trade_data.csv",index=False)
Market_price.to_csv("Cleaned_Market_data.csv",index=False)
Ref_data.to_csv("Cleaned_Ref_data.csv", index=False)
